# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/mikeydelgado/Desktop/2010.csv")
df
# Out:
#     Number                              title            artist     top genre  \
# 0        1                            bad guy     Billie Eilish    electropop
# 1        2                            7 rings     Ariana Grande     dance pop
# 2        3              Old Town Road - Remix         Lil Nas X   country rap
# 3        4                          Se̱orita      Shawn Mendes  canadian pop
# 4        5         rockstar (feat. 21 Savage)       Post Malone       dfw rap
# ..     ...                                ...               ...           ...
# 95      96  Stereo Hearts (feat. Adam Levine)  Gym Class Heroes     dance pop
# 96      97                           Dynamite         Taio Cruz     dance pop
# 97      98                   Break Your Heart         Taio Cruz     dance pop
# 98      99                         Summer Air     ItaloBrothers     dance pop
# 99     100                     All I Wanna Do     Martin Jensen      big room
#
# ...

# %%
df["top genre"].unique()
# Out:
# array(['electropop', 'dance pop', 'country rap', 'canadian pop',
#        'dfw rap', 'emo rap', 'canadian hip hop', 'modern rock',
#        'conscious hip hop', 'canadian contemporary r&b', 'brostep', 'pop',
#        'big room', 'electronic trap', 'electro house', 'boy band',
#        'alternative r&b', 'neo mellow', 'atl hip hop', 'complextro',
#        'edm', 'celtic rock', 'irish pop', 'indie poptimism',
#        'australian pop', 'aussietronica'], dtype=object)

# %%
Happy = ['electropop', 'dance pop', 'country rap', 'canadian pop',
       'dfw rap', 'canadian hip hop', 'conscious hip hop', 'electronic trap', 'electro house']

Neutral = 
sad = [ 'canadian contemporary r&b', 'alternative r&b', 'neo mellow', 'indie poptimism', 'emo rap']

anger = ['brostep', 'celtic rock',  'modern rock']

#angry, happy, sad, contempt, neutral, 

{"Happy": 1,
            "Neutral": 2,
            "Sad":3 ,
            "Anger": 4 ,
            "Surprise": 5 ,
   7, 
            "Fear": 8})
